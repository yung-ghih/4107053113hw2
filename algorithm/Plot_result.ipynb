# %% [markdown]
# <a href="https://colab.research.google.com/github/cheng0908/algorithm_TSP/blob/main/Plot2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
result_ant_BestScore=[309.9203982274287, 307.54544082371996, 368.50668720875524, 390.807272620497, 437.1281112825533, 386.6915053366695, 449.32777031827266, 452.7128300543534, 483.25994089760417, 454.99645300884845, 523.9275757586255, 561.7618705730742, 548.6681312640692, 585.9064051339781, 550.430573865488, 604.609444063287]
result_ant_Runtime=[0.03410940170288086, 0.14632039070129393, 0.055251359939575195, 0.10451774597167969, 0.10769457817077636, 0.5743653297424316, 0.42046165466308594, 0.7655512809753418, 0.5765969276428222, 0.6882553100585938, 1.5210821151733398, 1.6780318737030029, 1.0823177337646483, 1.1970176219940185, 1.5395104885101318, 1.855351161956787]
result_DP_optimal_cost=[193.34846101909935, 185.87941817689742, 238.9966792327712, 271.6259872747312, 325.8008926289404, 288.7948040337449, 350.65982406853664, 362.19165225046356, 370.222760289401, 363.9564169723223, 435.2509030145647, 446.936320235131, 423.5984776151247, 470.5859275655155, 434.8185654199742, 502.14862321399977]
result_DP_runtime=[0.0, 0.00019936561584472657, 0.000797891616821289, 0.00280146598815918, 0.0071947574615478516, 0.016754007339477538, 0.06703991889953613, 0.10741195678710938, 0.26580109596252444, 0.6712959289550782, 1.6821282863616944, 4.986975383758545, 16.030360460281372, 54.50038638114929, 245.28791847229004, 1708.6250873088836]
result_relative_error=[0.602911120129444, 0.6545427344249357, 0.5418904078154473, 0.438769819270724, 0.3417032340068053, 0.33898359643439285, 0.2813779608537399, 0.24992618477383466, 0.3053220729050874, 0.25013993926489675, 0.2037369069883203, 0.2569170262947842, 0.29525520099385466, 0.2450572165747722, 0.2658856305591475, 0.20404481086393758]

# %% [markdown]
# # **ANT**

# %%
sns.set_style('darkgrid')
plt.figure(figsize=(19,10))
plt.plot(range(4,(len(result_ant_BestScore)+4)),result_ant_BestScore,color="blue",linestyle="dashed",marker="o",markerfacecolor="red",markersize=10)
plt.title("Result of ant algorithm ", fontsize=24)
plt.xlabel("Number of points", fontsize=24)

plt.ylabel("Total Weight", fontsize=24)
# Out:
# Text(0, 0.5, 'Total Weight')

# %%
plt.figure(figsize=(19,10))
plt.plot(range(4,(len(result_ant_BestScore)+4)),result_ant_Runtime,color="blue",linestyle="dashed",marker="o",markerfacecolor="red",markersize=10)
plt.title("Result of ant algorithm", fontsize=24)
plt.xlabel("Number of points", fontsize=24)

plt.ylabel("Run time(seconds)", fontsize=24)
# Out:
# Text(0, 0.5, 'Run time(seconds)')

# %% [markdown]
# # DP

# %%
plt.figure(figsize=(19,10))
plt.plot(range(4,(len(result_ant_BestScore)+4)),result_DP_runtime,color="blue",linestyle="dashed",marker="o",markerfacecolor="red",markersize=10)
plt.title("Result of DP algorithm ",fontsize=24)
plt.xlabel("Number of points",fontsize=24)

plt.ylabel("Run time(seconds)",fontsize=24)
# Out:
# Text(0, 0.5, 'Run time(seconds)')

# %%
plt.figure(figsize=(19,10))
plt.plot(range(4,(len(result_ant_BestScore)+4)),result_DP_optimal_cost,color="blue",linestyle="dashed",marker="o",markerfacecolor="red",markersize=10)
plt.title("Result of DP algorithm ", fontsize=24)
plt.xlabel("Number of points", fontsize=24)

plt.ylabel("Total Weight", fontsize=24)
# Out:
# Text(0, 0.5, 'Total Weight')

# %% [markdown]
# # Comparison

# %%
plt.figure(figsize=(19,10))
plt.plot(range(4,(len(result_ant_BestScore)+4)),result_relative_error,color="blue",linestyle="dashed",marker="o",markerfacecolor="red",markersize=10)
plt.title("Relative error between DP and ANT algorithm ", fontsize=24)
plt.xlabel("Number of points", fontsize=24)
plt.ylabel("Relative error", fontsize=24)
# Out:
# Text(0, 0.5, 'Relative error')

# %% [markdown]
# # Comparison

# %%
plt.figure(figsize=(19,10))
plt.plot(range(4,(len(result_ant_BestScore)+4)),result_DP_runtime,color="blue",linestyle="dashed",marker="o",markerfacecolor="red",markersize=10, label='DP')
plt.plot(range(4,(len(result_ant_BestScore)+4)),result_ant_Runtime,color="green",linestyle="dashed",marker="o",markerfacecolor="blue",markersize=10, label='Ant')
plt.title("Result of ant algorithm and dp ", fontsize=24)
plt.xlabel("Number of points", fontsize=24)
plt.legend(loc='best')
plt.ylabel("Run time(seconds)", fontsize=24)
# Out:
# Text(0, 0.5, 'Run time(seconds)')

# %%
plt.figure(figsize=(19,10))
plt.plot(range(4,(len(result_ant_BestScore)+4)),result_ant_BestScore,color="blue",linestyle="dashed",marker="o",markerfacecolor="red",markersize=10, label='Ant')
plt.plot(range(4,(len(result_ant_BestScore)+4)),result_DP_optimal_cost,color="red",linestyle="dashed",marker="o",markerfacecolor="blue",markersize=10, label='DP')

plt.title("Result of Ant algorithm and DP", fontsize=24)
plt.xlabel("Number of points", fontsize=24)
plt.legend(loc='best')
plt.ylabel("Total Weight", fontsize=24)
# Out:
# Text(0, 0.5, 'Total Weight')
