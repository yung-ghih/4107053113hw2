# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
result_ant_BestScore=[291.1070844839113, 291.8071495696941, 378.5997176516594, 370.60504340718745, 407.65857787098685, 372.044085223057, 432.0062786319893, 450.72046221819784, 477.7940003959476, 488.74938791414274, 505.19463854138667, 541.7634725656785, 562.508968092643, 558.0220886234365, 569.8274441461189, 571.7595081108337, 582.7373683143591]
result_ant_Runtime=[0.021149969100952147, 0.07559137344360352, 0.036302947998046876, 0.05086503028869629, 0.23317060470581055, 0.10491280555725098, 0.27168688774108884, 0.24555764198303223, 0.7342367172241211, 0.5247832775115967, 0.33829598426818847, 0.8936107158660889, 0.7386209964752197, 0.8126198291778565, 1.157504177093506, 1.7331111431121826, 1.8055565357208252]
result_DP_optimal_cost=[179.17864737448784, 187.22412380094178, 257.94712865685926, 259.3878567957944, 297.14429254090396, 261.6615212210067, 325.96766443446757, 352.4312740196667, 381.3105406937541, 372.04267314035474, 401.69776929496646, 431.28637160177135, 435.39146262305445, 441.28338844124, 481.5562636626298, 508.89729974528467, 527.523449617927]
result_DP_runtime=[0.0, 0.0003993988037109375, 0.000996875762939453, 0.0019979476928710938, 0.004986715316772461, 0.013171195983886719, 0.031900978088378905, 0.08636236190795898, 0.20904145240783692, 0.5411664962768554, 1.464484739303589, 4.343607187271118, 14.155804443359376, 49.37085690498352, 195.93051891326905, 879.9140421152115, 6804.77534588178]
result_relative_error=[0.6246750868449757, 0.5585980248995361, 0.4677415469714388, 0.4287678998749347, 0.3719212790024221, 0.4218524889978686, 0.325304089230727, 0.2788889506810519, 0.2530311895565543, 0.31369174344621453, 0.2576486033967057, 0.2561571805610317, 0.2919614103220075, 0.26454360902765117, 0.18330398157863095, 0.12352631542162458, 0.1046662830560845]

# %% [markdown]
# # **ANT**

# %%
sns.set_style('darkgrid')
plt.figure(figsize=(20,10))
plt.plot(range(4,(len(result_ant_BestScore)+4)),result_ant_BestScore,color="blue",linestyle="dashed",marker="o",markerfacecolor="red",markersize=10)
plt.title("Result of ant algorithm ", fontsize=24)
plt.xlabel("Number of points", fontsize=24)

plt.ylabel("Total Weight", fontsize=24)
# Out:
# Text(0, 0.5, 'Total Weight')

# %%
plt.figure(figsize=(20,10))
plt.plot(range(4,(len(result_ant_BestScore)+4)),result_ant_Runtime,color="blue",linestyle="dashed",marker="o",markerfacecolor="red",markersize=10)
plt.title("Result of ant algorithm", fontsize=24)
plt.xlabel("Number of points", fontsize=24)

plt.ylabel("Run time(seconds)", fontsize=24)
# Out:
# Text(0, 0.5, 'Run time(seconds)')

# %% [markdown]
# # DP

# %%
plt.figure(figsize=(20,10))
plt.plot(range(4,(len(result_ant_BestScore)+4)),result_DP_runtime,color="blue",linestyle="dashed",marker="o",markerfacecolor="red",markersize=10)
plt.title("Result of DP algorithm ",fontsize=24)
plt.xlabel("Number of points",fontsize=24)

plt.ylabel("Run time(seconds)",fontsize=24)
# Out:
# Text(0, 0.5, 'Run time(seconds)')

# %%
plt.figure(figsize=(20,10))
plt.plot(range(4,(len(result_ant_BestScore)+4)),result_DP_optimal_cost,color="blue",linestyle="dashed",marker="o",markerfacecolor="red",markersize=10)
plt.title("Result of DP algorithm ", fontsize=24)
plt.xlabel("Number of points", fontsize=24)

plt.ylabel("Total Weight", fontsize=24)
# Out:
# Text(0, 0.5, 'Total Weight')

# %% [markdown]
# # Comparison

# %%
plt.figure(figsize=(20,10))
plt.plot(range(4,(len(result_ant_BestScore)+4)),result_relative_error,color="blue",linestyle="dashed",marker="o",markerfacecolor="red",markersize=10)
plt.title("Relative error between DP and ANT algorithm ", fontsize=24)
plt.xlabel("Number of points", fontsize=24)
plt.ylabel("Relative error", fontsize=24)
# Out:
# Text(0, 0.5, 'Relative error')

# %% [markdown]
# # Comparison

# %%
plt.figure(figsize=(20,10))
plt.plot(range(4,(len(result_ant_BestScore)+4)),result_DP_runtime,color="blue",linestyle="dashed",marker="o",markerfacecolor="red",markersize=10, label='DP')
plt.plot(range(4,(len(result_ant_BestScore)+4)),result_ant_Runtime,color="green",linestyle="dashed",marker="o",markerfacecolor="blue",markersize=10, label='Ant')
plt.title("Result of ant algorithm and dp ", fontsize=24)
plt.xlabel("Number of points", fontsize=24)
plt.legend(loc='best')
plt.ylabel("Run time(seconds)", fontsize=24)
# Out:
# Text(0, 0.5, 'Run time(seconds)')

# %%
plt.figure(figsize=(20,10))
plt.plot(range(4,(len(result_ant_BestScore)+4)),result_ant_BestScore,color="blue",linestyle="dashed",marker="o",markerfacecolor="red",markersize=10, label='Ant')
plt.plot(range(4,(len(result_ant_BestScore)+4)),result_DP_optimal_cost,color="red",linestyle="dashed",marker="o",markerfacecolor="blue",markersize=10, label='DP')

plt.title("Result of Ant algorithm and DP", fontsize=24)
plt.xlabel("Number of points", fontsize=24)
plt.legend(loc='best')
plt.ylabel("Total Weight", fontsize=24)
# Out:
# Text(0, 0.5, 'Total Weight')
